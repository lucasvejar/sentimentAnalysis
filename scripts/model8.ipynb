# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import pathlib
import spacy
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras import layers
import keras
# Out:
# Using TensorFlow backend.

# %%
# Loading the dataset 
data_dir = pathlib.Path('/home/lv11/Documents/ProyectosPython/sentimentAnalysis/train')
nf = pd.read_csv(data_dir / 'tweetsDataset1.csv',skiprows=1,names=['Message','Target'])
#print(nf.head(20))

nlp = English()
stop_words = list(STOP_WORDS)
#print(stop_words)

def spacy_tokenizer(sentence):
    tokens = nlp(sentence)
    tokens = [ word.lemma_.lower().strip() if word.lemma_ != '-PRON-' else word.lower_ for word in tokens ]
    tokens = [ word for word in tokens if word not in stop_words and word not in punctuation ]
    return tokens

# %%
vectorizer = CountVectorizer(min_df=0, lowercase=False)
vectorizer.fit(nf['Message'])
#print(vectorizer.vocabulary_)

vectorizer.transform(nf['Message']).toarray()

messages = nf['Message']
labels = nf['Target']

# %%
x_train, x_test, y_train, y_test = train_test_split(messages,labels,test_size=0.25,random_state=1000,shuffle=True)

print(len(x_train))
print(len(x_test))
print(x_test)
# Out:
# 1727
# 576
# 108                          .Thanks so much for the RT.1
# 501             Why? You don't like blonde hair? unhappy
# 834                           25x25? I can go first happy
# 584      wow whattay decision both parties celebrating :D
# 1148                   Please return the jacket unhappy
#                               ...
# 236     are dying of thirst  and it's all because of u...
# 2071    thanks for the recent follow. Much appreciated...
# 1811                            because you are one happy
# 1299    That was a FUN night! Sorry I missed last nigh...
# 1367                 much appreciated happy   Want this ?
# Name: Message, Length: 576, dtype: object

# %%
vectorizer.fit(x_train)
X_train = vectorizer.transform(x_train).toarray()
X_test = vectorizer.transform(x_test).toarray()

# %%
features = 3749 #1549 #1998 #2817 #3603 #3749
shufle = True
drop = 0.5
layer1 = 512 #512
layer2 = 256 #256
epoch = 5
lr = 0.002
epsilon = 1e-9
validation = 0.1

# %%
model = Sequential()
model.add(layers.Dense(layer1, input_dim=features, activation='relu'))
model.add(layers.Dropout(drop))
model.add(layers.Dense(layer2,activation='sigmoid'))
model.add(layers.Dropout(drop))
model.add(layers.Dense(3,activation='softmax'))

# %%
optimizer = keras.optimizers.Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=epsilon,decay=0.0,amsgrad=False)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 512)               1920000
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 2,052,099
# Trainable params: 2,052,099
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(np.array(X_train),y_train,batch_size=32,epochs=epoch,verbose=1,validation_split=validation,shuffle=shufle)
# Out:
# Train on 1554 samples, validate on 173 samples
# Epoch 1/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.5053 - accuracy: 0.7407 - val_loss: 0.1963 - val_accuracy: 0.9075
# Epoch 2/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.1171 - accuracy: 0.9505 - val_loss: 0.1865 - val_accuracy: 0.9075
# Epoch 3/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0449 - accuracy: 0.9839 - val_loss: 0.2230 - val_accuracy: 0.8902
# Epoch 4/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0200 - accuracy: 0.9949 - val_loss: 0.2097 - val_accuracy: 0.8960
# Epoch 5/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.2560 - val_accuracy: 0.9017
# Epoch 6/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.2721 - val_accuracy: 0.8902
# Epoch 7/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.2928 - val_accuracy: 0.8902
# Epoch 8/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.3370 - val_accuracy: 0.8960
# Epoch 9/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.3367 - val_accuracy: 0.8960
# Epoch 10/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3417 - val_accuracy: 0.8960
# Epoch 11/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.3641 - val_accuracy: 0.8960
# Epoch 12/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 8.0654e-04 - accuracy: 1.0000 - val_loss: 0.3539 - val_accuracy: 0.8902
# Epoch 13/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 6.1893e-04 - accuracy: 1.0000 - val_loss: 0.3783 - val_accuracy: 0.8960
# Epoch 14/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 9.4627e-04 - accuracy: 0.9994 - val_loss: 0.4383 - val_accuracy: 0.8671
# Epoch 15/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 8.4275e-04 - accuracy: 1.0000 - val_loss: 0.3702 - val_accuracy: 0.8902
# Epoch 16/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 7.2248e-04 - accuracy: 1.0000 - val_loss: 0.4387 - val_accuracy: 0.8728
# Epoch 17/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 5.6022e-04 - accuracy: 1.0000 - val_loss: 0.4932 - val_accuracy: 0.8728
# Epoch 18/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 4.1946e-04 - accuracy: 1.0000 - val_loss: 0.4725 - val_accuracy: 0.8728
# Epoch 19/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 8.0840e-04 - accuracy: 0.9994 - val_loss: 0.5304 - val_accuracy: 0.8671
# Epoch 20/30
# 1554/1554 [==============================] - 2s 2ms/step - loss: 3.3932e-04 - accuracy: 1.0000 - val_loss: 0.4771 - val_accuracy: 0.8786
# Epoch 21/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 2.4721e-04 - accuracy: 1.0000 - val_loss: 0.5156 - val_accuracy: 0.8671
# Epoch 22/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 1.6933e-04 - accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.8786
# Epoch 23/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 1.6232e-04 - accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.8786
# Epoch 24/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 1.3478e-04 - accuracy: 1.0000 - val_loss: 0.4929 - val_accuracy: 0.8786
# Epoch 25/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 2.8136e-04 - accuracy: 1.0000 - val_loss: 0.5483 - val_accuracy: 0.8728
# Epoch 26/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 1.4425e-04 - accuracy: 1.0000 - val_loss: 0.5470 - val_accuracy: 0.8728
# Epoch 27/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 1.8120e-04 - accuracy: 1.0000 - val_loss: 0.5498 - val_accuracy: 0.8728
# Epoch 28/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 1.7065e-04 - accuracy: 1.0000 - val_loss: 0.5295 - val_accuracy: 0.8728
# Epoch 29/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 1.8376e-04 - accuracy: 1.0000 - val_loss: 0.5225 - val_accuracy: 0.8786
# Epoch 30/30
# 1554/1554 [==============================] - 3s 2ms/step - loss: 7.8246e-04 - accuracy: 0.9994 - val_loss: 0.6730 - val_accuracy: 0.8555

# %%
pred = model.predict(X_test)

# %%
xtest = [x for x in x_test]
for i in range(len(pred)):
    sent = (1 if pred[i][1] > 0.5 else 0)
    print("tweet=",xtest[i], " || prediction=",sent)
# Out:
# snap chat unhappy   || prediction= 0
# tweet=  it's just got 3 years longer unhappy     || prediction= 0
# tweet= so sorry I havent been checking my tweets unhappy  We are all here for you!  || prediction= 0
# tweet= Alright. Looks like back to chores behind the scenes. My page hits drop to 1K daily when I don't visit and post. unhappy   || prediction= 0
# tweet= come back callie  gabbie d ghost unhappy  i love you both  || prediction= 0
# tweet= unhappy  :/ unhappy   feeling sick  || prediction= 0
# tweet= same unhappy    || prediction= 0
# tweet= Thanks for the recent follow Happy to connect happy  have a great Thursday..10  || prediction= 1
# tweet= Koalas are dying of thirst  and it's all because of us unhappy  .8  || prediction= 0
# tweet= Definitely my arms unhappy  .14  || prediction= 0
# tweet= unhappy  oh man..  || prediction= 0
# tweet= good crying with joy  i love you so much  || prediction= 1
# tweet= Guess who's not getting a unicorn frappuccino because they're sold out unhappy .1  || prediction= 0
# tweet=  the Mini and the Campervan happy  || prediction= 1
# tweet= it feels kind of empty w/o youngjae at the venue.. unhappy   || prediction= 0
# tweet= Well that's my weekend viewing plans changed! unhappy   || prediction= 0
# tweet= i hope this little beaand is andot overworkiandg himself and gettiandg at least some rest unhappy    || prediction= 0
# tweet= minah starts crying because of the fans and yura  hyeri make her laugh to cheer her up.. I can't crying with joy  || prediction= 1
# tweet= tonight 7pm.1  || prediction= 1
# tweet= Ravel Morrison unhappy    || prediction= 0
# tweet= Koalas are dying of thirst  and it's all because of us unhappy  .4  || prediction= 0
# tweet= talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.6  || prediction= 0
# tweet= My new video for happy  I hope you like ithappy  || prediction= 1
# tweet=  you've got the message happy  || prediction= 1
# tweet= it's just a cut during one of my kitchen experiments happy  || prediction= 1
# tweet=  Give a little for her happy  || prediction= 1
# tweet= thanks for the recent follow. Much appreciated happy  || prediction= 1
# tweet= NOOOO in here is 6.45 ;_; I have classes at that time unhappy   || prediction= 0
# tweet= I've tried resetting everything  || prediction= 0
# tweet= mata_tytan: almightyTANNER: good evening everyone happy  join our twitter party tonight. official tagline:TANN  || prediction= 1
# tweet= You deserve better . Hope you'll be okay unhappy    || prediction= 0
# tweet= how about me unhappy   || prediction= 0
# tweet= instant message still bored unhappy   || prediction= 0
# tweet= I wish I was meeting OA again unhappy   || prediction= 0
# tweet= That would be a great trick happy.1  || prediction= 1
# tweet= Have you ever been to AUSTRALIA! :D Love your vids. Lovo on youtube :D  || prediction= 1
# tweet= oh my god not laurie penny unhappy   || prediction= 0
# tweet= i miss you huhu so busy unhappy   || prediction= 0
# tweet= You know what really upsets me? When a stranger on the internet isn't satisfied with the entertainment I provide him for  || prediction= 1
# tweet= Hellooo.. happy  pussy (creepz_x)  || prediction= 1
# tweet=  DM us happy  S  || prediction= 1
# tweet= Wow  || prediction= 0
# tweet= Oh that feel when you have 10 gems :D  || prediction= 0
# tweet= I suppose they are waiting for you happy  || prediction= 1
# tweet= There're time we shcj do/did something that dissapointed ot6  || prediction= 1
# tweet=  if i get 900 retweets and 900 likes. help me :(un.2  || prediction= 0
# tweet= Ok will do! I never had any problems with the old ticket app  || prediction= 1
# tweet= usually a speedboat behind any we get here on the river unhappy    || prediction= 0
# tweet=  have a great  || prediction= 0
# tweet= thanks for the recent follow. Much appreciated happy  Want this.1  || prediction= 1
# tweet= i miss so much unhappy   || prediction= 0
# tweet= it can't be over unhappy   || prediction= 0
# tweet= New twitter account piss off no idea MAJA SALVADOR is Follow not applicable guys happy  || prediction= 1
# tweet= fuck unhappy   || prediction= 0
# tweet=  Who hacked me unhappy   || prediction= 0
# tweet=  but in reality they're just patches of dusty dirt unhappy   || prediction= 0
# tweet=  but not your career. unhappy   || prediction= 0
# tweet= Hi! We tried to call your number but got no response unhappy  Please share another suitable time and an alternate number for us to.. cont1  || prediction= 0
# tweet= congratulations David! Well done Mrs V! Welcome Jessica! happy  || prediction= 1
# tweet= unhappy  how come people like this have children where's the state intervention   || prediction= 0
# tweet= Exaseetly what's happening in TN Politisees. This is not to get BJP at all to TN. Game is different. Again.1  || prediction= 1
# tweet= Would really like it if the coandsole versioands and got the update to makr it like the Steam versioand. =(  || prediction= 0
# tweet= That would be a great trick happy.3  || prediction= 1
# tweet=  I bet The media's one-sided view of Tim Tams surprisingly was the alt-right roar extreme droll Fad unhappy   || prediction= 0
# tweet= Happy belated birthday :)Another duet of you and Amaal is much needed  || prediction= 1
# tweet= One table last night told me I look like a graceful ballerina gliding through tables- then another told me I looked like a flash dancer unhappy   || prediction= 0
# tweet= Well that's not good unhappy   || prediction= 0
# tweet= i left my headphones at home unhappy  kms  || prediction= 0
# tweet= Another great song  Have a listen. Its good! You may well like it happy  || prediction= 1
# tweet= As in most used. Stats don't care about motivation happy  || prediction= 1
# tweet= I wish I could say the gangs all here but Daniel's not in this picture. unhappy   Rantoul Twp High   || prediction= 0
# tweet= Yeah did update to 16.04   || prediction= 0
# tweet= Right I seriously need a decent Butterfly Tattoo design  || prediction= 0
# tweet= Superstar thanks so much for the kind words! Look forward to seeing you soon buddy smile  || prediction= 1
# tweet= talking to my over driver about where I'm goinghe said he'd love to go to New York too but since Trump it's probably not.3  || prediction= 0
# tweet= Is that store still in use? If so  || prediction= 1
# tweet= Can I pop in a request for assassin shower gel? happy  || prediction= 1
# tweet= Thats grim unhappy   || prediction= 0
# tweet= instant message so jealous okay unhappy  but never mind haha bruno can wait finals first  || prediction= 0
# tweet= mom please stop making cookies  || prediction= 0
# tweet=  Mike. Blessings to you. happy  || prediction= 1
# tweet= right i don%27t see how people can just do shit like this   || prediction= 1
# tweet= don't rt to save a guy's life   || prediction= 1
# tweet=  rocks. next question - where is my astro unhappy  ?   || prediction= 0
# tweet= Her back unhappy    || prediction= 0
# tweet= only way to make sense of those crazy edge cases is the idea of sharing revenue was offensive  || prediction= 0
# tweet=  you need a direct coffee feed to Starbucks happy  || prediction= 0
# tweet=  still strict  || prediction= 0
# tweet= please meeeee you have followed me for almost to  years now unhappy   || prediction= 0
# tweet= Someone asked me Hows life? I just smiled and replied  || prediction= 0
# tweet=  or SHIT for short :)*Thanks to my friend maddy over at  || prediction= 1
# tweet= i really feel for that lamp unhappy   || prediction= 0
# tweet=  huh? happy  || prediction= 1
# tweet= ally unhappy  I can't make a poem about being cute   || prediction= 0
# tweet= stay cool   || prediction= 1
# tweet= One by one Allah ease my problem . Lot of thanks to Him crying with joy  || prediction= 1
# tweet=  when you have to do things like this happy  || prediction= 1
# tweet= Yesterday's faci so cute! But he 30+ :(Today's faci is old eeyer  || prediction= 0
# tweet=  owner told me about it (as in article) smile  || prediction= 1
# tweet=  I can't wait to actually see a copy smile  || prediction= 0
# tweet= oh yes happy  || prediction= 0
# tweet= I miss snsd. I miss my girls unhappy   || prediction= 0
# tweet= Thanks for sharing happy  || prediction= 1
# tweet=  I really liked  happy  || prediction= 1
# tweet= I'm not lost  || prediction= 0
# tweet= I miss you crying   || prediction= 0
# tweet= easter has flown unhappy  I'm not ready to give up home luxuries like branded cereal  || prediction= 0
# tweet= Nooo your hair color is pretty   || prediction= 1
# tweet= I love laying in a meadow of flowers listening to Mellow's music ...a great way to relax smile  || prediction= 1
# tweet= The biblical lectures are coming. More notification soon. Tomorrow  || prediction= 1
# tweet= I'm scared unhappy  I mean. Why the heck did I decide to do laundry at 7:30 pm? What is wrong with me. Did I mention how dark it is. FML  || prediction= 0
# tweet= a little video i made for the love of my life  || prediction= 1
# tweet= Don't say that unhappy   || prediction= 0
# tweet= i miss hoseok unhappy    || prediction= 0
# tweet= Am bored and kandowiandg I have ando plaands for today is makiandg me eveand more bored unhappy   || prediction= 0
# tweet= More than just a picture unhappy    || prediction= 0
# tweet=  the new one just seems a bit unstable unhappy   || prediction= 0
# tweet= Stats for the day have arrived. 1 new follower and NO unfollowers happy  via  || prediction= 1
# tweet= Good morning every one.2  || prediction= 1
# tweet= [thinks about how tfp soundwave is forever trapped in the void realm] unhappy .1  || prediction= 0
# tweet= I understand that look sad   || prediction= 0
# tweet= i hope this little beaand is andot overworkiandg himself and gettiandg at least some rest unhappy  .1  || prediction= 0
# tweet= Missing in crying  Seaside area.   || prediction= 0
# tweet= Koalas are dying of thirst  and it's all because of us unhappy  .7  || prediction= 0
# tweet= Hey Tony  || prediction= 1
# tweet= me everything and anything these days  || prediction= 0
# tweet= Jyoust a reminder... thank you for this happy  || prediction= 1
# tweet=  i don%27t know if you saw my comment yet  || prediction= 1
# tweet= no one is selling vhope banners what?  sad   || prediction= 0
# tweet= 515 SUBSCRIBERS!!!! :DTHE CONTINUES!  || prediction= 0
# tweet= Also please send prayers and sympathy because my favorite ball dress doesn't fit my boobs crying    || prediction= 0
# tweet= 3. That's a lot cheaper and easier than make your own. My schematic needs special cables that doesn't come easy. unhappy   || prediction= 0
# tweet=  dealer said loads of cars were returning due to disabled losing them sad   || prediction= 0
# tweet= Thanks for up-voting us on PH happy.1  || prediction= 1
# tweet= YG should have sent them to MCD. I want to see them holding the trophy unhappy  anyways   || prediction= 0
# tweet= Rose come to him! He's really your enthusiast :-D using SO MUCH not SO MAY!  :-)~~~  || prediction= 0
# tweet= Hi Mr. Yen! Will you be doing any signings in New York some day? Your a great role model happy  || prediction= 1
# tweet= i am if you're still looking for one happy  || prediction= 1
# tweet= I've had it since December  my hairs stopped snapping off! It's made a massive difference! Get the  || prediction= 1
# tweet= Merry Christmas everyone happy  || prediction= 1
# tweet= Hey thanks for being my top new followers this week! Much appreciated happy   Want this ?  || prediction= 1
# tweet= We bought a 523 litre fridge. I am applying for cold storage license in Bhayander West :D  || prediction= 0
# tweet= Cheers :D  || prediction= 0
# tweet= last to  things i've bought from you no sweets unhappy   || prediction= 0
# tweet= Let's have dinneeeer please unhappy   || prediction= 0
# tweet= Thanks for the recent follow Happy to connect happy  have a great Thursday..32  || prediction= 1
# tweet= OPENING UP TO YOU LOT!RT LIKES WOULD BE LAAAAAVERLY :D .xxENJOY.1  || prediction= 1
# tweet= HAPPY BIRTHDAY KATRIKA  I miss you though unhappy  miss having you in our group and all haih  anyway  || prediction= 0
# tweet= Ma de tonight i don%27t really care crying with joy  || prediction= 1
# tweet= I hate when my mom ask so you going or no? Bc then I want to stay home but i missed too much school already unhappy   || prediction= 0
# tweet= Roc Boyz sad    || prediction= 0
# tweet=  this freaking chapter of One Piece!! It's definitely a good one! :D  || prediction= 1
# tweet= Her back unhappy  .2  || prediction= 0
# tweet= this is damn.... theres people who sincerely want to attend BH birthday party but bcs of those people who try for fun make them ca.16  || prediction= 0
# tweet= Thanks for the recent follow Happy to connect happy  (Want this? It's FREE!  || prediction= 1
# tweet= Ye... I will miss you unhappy   || prediction= 0
# tweet= i tried fixing my choristers dress hem that came undone by taping it with fabric tape but i put it on wrong and its even more ruined unhappy   || prediction= 0
# tweet= Guys please help me retweet unhappy    || prediction= 0
# tweet= WUT I TOTALLY MISSED YOUR BDAY unhappy  Happy belated Birthday sweetheart  || prediction= 0
# tweet= Follow  to a Saga diary and a year's worth of Saga pens :)TCs  || prediction= 0
# tweet= Mmmm... the blood of my enemies... happy  || prediction= 1
# tweet= i can't continue this right now because the lighting is shitty as f i swear sorry sad   || prediction= 0
# tweet=  I have a cold unhappy  we'll see how I feel today!  || prediction= 0
# tweet= i want harry's phonecase sad   || prediction= 0
# tweet= Did you notice? There is no killings of RSS / BJP workers in another Southern State? CM is dismantling Xtian infra in Munnar?  || prediction= 1
# tweet= That would be a great trick happy.9  || prediction= 1
# tweet= Wtf?! Where's the What is this boring show that's on?! When did this happen?? This is what happens when I close all week. unhappy   || prediction= 0
# tweet= tell me unhappy  why  || prediction= 0
# tweet=  man. : (   || prediction= 0
# tweet= New Upcoming Heroes REVEALED! WUKONG  || prediction= 0
# tweet= Perfect  || prediction= 0
# tweet= Thanks for the recent follow Happy to connect happy  have a great Thursday.  Want this.3  || prediction= 1
# tweet= Offline  unhappy   || prediction= 0
# tweet=  instead of just money  || prediction= 0
# tweet= Nothing could be better happy  || prediction= 1
# tweet= They stopped having them when they got rid of the toy surprises at the bottom unhappy   || prediction= 0
# tweet= A Chub bun because its Easter! Happy Easter!  His name is Almond! :D  || prediction= 1
# tweet= good morning i had a nightmare and i'm still wondering why maddie hates me. this is only the beginning of the day unhappy   || prediction= 0
# tweet=  oh no unhappy  Could you please tell me a little more about your issue? Im following if youd prefer to DM. Amanda  || prediction= 0
# tweet= Do It Like It's Legal sweaters  ..More designs available at  || prediction= 1
# tweet=  Anne! happy  || prediction= 1
# tweet=  yes it would have if it hadn't been for those meddling clouds smile  || prediction= 0
# tweet= today hasn't been great unhappy    || prediction= 0
# tweet=  congratulations to both of you. happy  || prediction= 1
# tweet= Sixth spot not applicable Team! Higher pa! :)KISSES TheFashionIcon.1  || prediction= 1
# tweet= how do we book the cars service for the swards tommorow :D  || prediction= 0
# tweet=  I'm a joke unhappy   || prediction= 0
# tweet= Hello everyone  || prediction= 1
# tweet=  Keep  || prediction= 0
# tweet=  hindi close friend? unhappy  || prediction= 0
# tweet= please just stop confining animals in zoos unhappy    || prediction= 0
# tweet= sadly I'm not unhappy   || prediction= 0
# tweet= Awesome! makes a good nurse maid  || prediction= 0
# tweet= I miss Louis' tweets unhappy   || prediction= 0
# tweet= friendly fire to wings tour unhappy   || prediction= 0
# tweet=  rather  || prediction= 1
# tweet= i wasn't saying i read a book today.1  || prediction= 0
# tweet= Swear I just walked past haha  || prediction= 0
# tweet= Hi Carlo! I'm okay nmn. Howdy? happy  || prediction= 1
# tweet=  I really appreciate it. Hope you have a brilliant day happy  || prediction= 1
# tweet=  we've invited 24 people to propose visions of the future. Jom happy  || prediction= 1
# tweet= That would be a great trick happy  || prediction= 1
# tweet= Nothing could be better happy.3  || prediction= 1
# tweet= i miss them already unhappy    || prediction= 0
# tweet= Congratulations very impressive happy  || prediction= 1
# tweet=  that's Europe  || prediction= 0
# tweet= AVI for my man :)Phone made like always wink.1  || prediction= 1
# tweet= Zac farro is back By the way hehehe So sad Jeremy is not unhappy   || prediction= 0
# tweet= Dammit the effect of the linearts doesn't show so nicely on twitter unhappy   || prediction= 0
# tweet= the email I was hoping I'd get today  || prediction= 0
# tweet= why are your campervan tickets so expensive? unhappy   || prediction= 0
# tweet= Fri or Thu? I'm going to the Friday showing :D  || prediction= 0
# tweet= SHOULD I STAY ? SHOULD I GO ? NOBODY KNOWS happy  || prediction= 1
# tweet= Claaaaaaaaaaaaasse !   || prediction= 0
# tweet= Shihaaaa help me on my bishie hunttt equals  ^ equals )  || prediction= 1
# tweet=  i got goosebumps   || prediction= 0
# tweet= Hi ! I want to speak to you about a business partnership. happy  || prediction= 1
# tweet=  much appreciated happy  || prediction= 1
# tweet= wowwow these are all so cute unhappy  i wantt .1  || prediction= 0
# tweet= Ok. Just please read the replies on this....  || prediction= 0
# tweet= Thanks Lala.. Much needed happy  || prediction= 1
# tweet= But  || prediction= 0
# tweet= Think it would drive me mad once the synths and other robots turned up. unhappy   || prediction= 0
# tweet= I'm a building a LLVM backend so  || prediction= 0
# tweet= Oh no Andy unhappy   || prediction= 0
# tweet=  much appreciated happy   Want this.1  || prediction= 1
# tweet= philippines? unhappy    || prediction= 0
# tweet=  isn't it? smile  Britain co  || prediction= 1
# tweet= Please follow me . I have been trying to get your follow for a long time unhappy  .   || prediction= 0
# tweet= Ps4 mate  || prediction= 0
# tweet= Will you do before and after pictures? I always enjoy your swanky hair happy  || prediction= 1
# tweet= This is so damn touching. unhappy    || prediction= 0
# tweet= Can't :(Tello  || prediction= 0
# tweet= Tara  || prediction= 0
# tweet= this is jimin to yoongi unhappy  .7  || prediction= 0
# tweet=  I guess it's a good thing then to bring it right to the foreground and put it right in their face  || prediction= 0
# tweet= happy birthday ! happy  hope you have a good one  || prediction= 1
# tweet= Surround yourself with positivity happy.1  || prediction= 1
# tweet= why am i not in aus with alisha unhappy  imagine the things we could be doing  || prediction= 0
# tweet= but like HOW LONG IS A WHILE?! i didn't want him to be back but he puts me in such a good mood so i don't want him   || prediction= 0
# tweet= this is damn.... theres people who sincerely want to attend BH birthday party but bcs of those people who try for fun make them ca.7  || prediction= 0
# tweet= thanks for the recent follow. Much appreciated happy   Want this  || prediction= 1
# tweet= So I may be one of those workers who are not properly compensated unhappy   || prediction= 0
# tweet=  find out more and sign up at  || prediction= 0
# tweet=  Thank you happy  || prediction= 1
# tweet= Who wants some good vibes? Watch this on YouTube or TV100 application now for FREE happy.3  || prediction= 1
# tweet= Thanks for the recent follow Happy to connect happy  have a great Thursday..29  || prediction= 1
# tweet=  it's been so much fun and I absolutely love the kids!! Don't want it to be over so soon unhappy   || prediction= 0
# tweet= .I can't believe this hasn't been fixed yet  || prediction= 0
# tweet= are dying of thirst  and it's all because of us unhappy   .1  || prediction= 0
# tweet= thanks for the recent follow. Much appreciated happy   Want this ?.3  || prediction= 1
# tweet= because you are one happy  || prediction= 1
# tweet= That was a FUN night! Sorry I missed last night unhappy  We really need to sync our calendars with and   || prediction= 0
# tweet=  much appreciated happy   Want this ?  || prediction= 1

# %%
plt.title('Model loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training','validation'],loc='upper right')
plt.show()

# %%
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'], loc='lower right')
plt.show()

# %%
test_loss, test_acc = model.evaluate(X_test,y_test)
print("test loss:", test_loss)
print("test accuracy:", test_acc)
# Out:
# 576/576 [==============================] - 0s 230us/step
# test loss: 0.8537120851170685
# test accuracy: 0.8420138955116272
